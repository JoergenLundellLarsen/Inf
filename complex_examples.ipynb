# %%
#collaborators Jørgen og Peder
from complex import Complex

z = Complex(1, 2)
y = Complex(3, 4)
print(z)
print([z,y])
print(z.real,z.imag)
print(Complex())
print(Complex(5))
print(z * y)
print(z + y)
print(z - y)

print(z + 3)    # 4+2i
print(3 + z)    # 4+2i
print(z * 3)    # 3+6i
print(3 * z)    # 3+6i
print(z - 3)    # -2+2i
print(3 - z)    # 2-2i

print(z==y)
print(z!=y)
# Out:
# 1+2i
# [Complex(1, 2), Complex(3, 4)]
# 1 2
# 0+0i
# 5+0i
# -5+10i
# 4+6i
# -2-2i
# 4+2i
# 4+2i
# 3+6i
# 3+6i
# -2+2i
# 2-2i
# False
# True
